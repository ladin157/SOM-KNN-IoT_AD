# %% [markdown]
# # NBaIoT SOMKNN CLASSIFY
#
# ## Device 2
#
# - Training on device 2 (using both Mirai and Gafgyt).
# - Testing on device 2 (both Mirai & Gafgyt)

# %% [markdown]
# # Imports

# %%
# import sys
import sys
import os
import random
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
print(os.path.dirname(os.getcwd()))
sys.path.append(os.path.dirname(os.getcwd()))
# Out:
# /home/ladin/projects/research/papers/SOM-KNN-IoT_AD

# %%
from utils.config import data_path, nbaiot_1K_data_path, nbaiot_10K_data_path, nbaiot_5K_data_path, \
    nbaiot_20K_data_path, nbaiot_data_path, dn_nbaiot
from utils.datasets import get_data, get_data_d3

# %%
# from pyscripts.main_som import main, process_train_test_partial, som_test, load_common_data, load_data_test
from pyscripts.main_som import process_train_partial, som_test, load_data_test

# %% [markdown]
# ## Set folder and gafgyt params

# %%
choose_folder = nbaiot_data_path

# %%
print(choose_folder)
# Out:
# /home/ladin/projects/research/iot-anomaly-detection/data/nbaiot

# %% [markdown]
# ## Set training and testing devices

# %%
train_index = 2

# %%
train_index
# Out:
# 2

# %% [markdown]
# # 1. Load data and preprocess data

# %%
# Load data on device 1
data_benign, target_benign, data_gafgyt, target_gafgyt, data_mirai, target_mirai = get_data(choose_folder=choose_folder, choose_index=train_index)

# %%
(data_benign.shape, target_benign.shape), (data_gafgyt.shape, target_gafgyt.shape), (data_mirai.shape, target_mirai.shape)
# Out:
# (((13113, 115), (13113,)),
#  ((310630, 115), (310630,)),
#  ((512133, 115), (512133,)))

# %% [markdown]
# ## Split data

# %%
data_benign_train, data_benign_test, target_benign_train, target_benign_test = train_test_split(data_benign, target_benign, test_size=0.3, shuffle=True, random_state=1)

data_gafgyt_train, data_gafgyt_test, target_gafgyt_train, target_gafgyt_test = train_test_split(data_gafgyt, target_gafgyt, test_size=0.3, shuffle=True, random_state=1)

data_mirai_train, data_mirai_test, target_mirai_train, target_mirai_test = train_test_split(data_mirai, target_mirai, test_size=0.3, shuffle=True, random_state=1)

# %%
data_benign_train.shape, data_benign_test.shape, target_benign_train.shape, target_benign_test.shape
# Out:
# ((9179, 115), (3934, 115), (9179,), (3934,))

# %%
data_gafgyt_train.shape, data_gafgyt_test.shape, target_gafgyt_train.shape, target_gafgyt_test.shape
# Out:
# ((217441, 115), (93189, 115), (217441,), (93189,))

# %%
data_mirai_train.shape, data_mirai_test.shape, target_mirai_train.shape, target_mirai_test.shape
# Out:
# ((358493, 115), (153640, 115), (358493,), (153640,))

# %% [markdown]
# ## Set ratio

# %%
benign_size = data_benign_train.shape[0]
print(benign_size)
# Out:
# 9179

# %%
# ratio_001 = int(0.01*benign_size)
# ratio_01 = int(0.1*benign_size)
# ratio_05 = int(0.5*benign_size)
ratio_1 = int(1.0*benign_size)
# ratio_2 = int(2.0*benign_size)
# ratio_5 = int(5.0*benign_size)

# %% [markdown]
# ## Get train data of benign and gafgyt by ratio

# %%
# train 0.01
# data_gafgyt_001, _, target_gafgyt_001, _ = train_test_split(data_gafgyt_train, target_gafgyt_train, train_size=ratio_001, shuffle=True, random_state = 1)

# train 0.1
# data_gafgyt_01, _, target_gafgyt_01, _ = train_test_split(data_gafgyt_train, target_gafgyt_train, train_size=ratio_01, shuffle=True, random_state = 1)

# # train 0.5
# data_gafgyt_05, _, target_gafgyt_05, _ = train_test_split(data_gafgyt_train, target_gafgyt_train, train_size=ratio_05, shuffle=True, random_state = 1)

# train 1.0
data_gafgyt_1, _, target_gafgyt_1, _ = train_test_split(data_gafgyt_train, target_gafgyt_train, train_size=ratio_1, shuffle=True, random_state = 1)

# # train 2.0
# data_gafgyt_2, _, target_gafgyt_2, _ = train_test_split(data_gafgyt_train, target_gafgyt_train, train_size=ratio_2, shuffle=True, random_state = 1)

# train 5.0
# data_gafgyt_5, _, target_gafgyt_5, _ = train_test_split(data_gafgyt_train, target_gafgyt_train, train_size=ratio_5, shuffle=True, random_state = 1)

# %%
# print(data_gafgyt_001.shape, target_gafgyt_001.shape)
# print(data_gafgyt_01.shape, target_gafgyt_01.shape)
# print(data_gafgyt_05.shape, target_gafgyt_05.shape)
print(data_gafgyt_1.shape, target_gafgyt_1.shape)
# print(data_gafgyt_2.shape, target_gafgyt_2.shape)
# print(data_gafgyt_5.shape, target_gafgyt_5.shape)
# Out:
# (9179, 115) (9179,)

# %%
# 0.01
# X_train_gafgyt_001 = np.vstack([data_benign_train, data_gafgyt_001])
# y_train_gafgyt_001 = np.hstack([target_benign_train, target_gafgyt_001])

# 0.1
# X_train_gafgyt_01 = np.vstack([data_benign_train, data_gafgyt_01])
# y_train_gafgyt_01 = np.hstack([target_benign_train, target_gafgyt_01])

# # 0.5
# X_train_gafgyt_05 = np.vstack([data_benign_train, data_gafgyt_05])
# y_train_gafgyt_05 = np.hstack([target_benign_train, target_gafgyt_05])

# 1.0
X_train_gafgyt_1 = np.vstack([data_benign_train, data_gafgyt_1])
y_train_gafgyt_1 = np.hstack([target_benign_train, target_gafgyt_1])

# # 2.0
# X_train_gafgyt_2 = np.vstack([data_benign_train, data_gafgyt_2])
# y_train_gafgyt_2 = np.hstack([target_benign_train, target_gafgyt_2])

# 5.0
# X_train_gafgyt_5 = np.vstack([data_benign_train, data_gafgyt_5])
# y_train_gafgyt_5 = np.hstack([target_benign_train, target_gafgyt_5])

# %%
# print(X_train_gafgyt_001.shape, y_train_gafgyt_001.shape)
# print(X_train_gafgyt_01.shape, y_train_gafgyt_01.shape)
# print(X_train_gafgyt_05.shape, y_train_gafgyt_05.shape)
print(X_train_gafgyt_1.shape, y_train_gafgyt_1.shape)
# print(X_train_gafgyt_2.shape, y_train_gafgyt_2.shape)
# print(X_train_gafgyt_5.shape, y_train_gafgyt_5.shape)
# Out:
# (18358, 115) (18358,)

# %% [markdown]
# ## Get train data of benign and Mirai by ratio

# %%
# train 0.01
# data_mirai_001, _, target_mirai_001, _ = train_test_split(data_mirai_train, target_mirai_train, train_size=ratio_001, shuffle=True, random_state = 1)

# train 0.1
# data_mirai_01, _, target_mirai_01, _ = train_test_split(data_mirai_train, target_mirai_train, train_size=ratio_01, shuffle=True, random_state = 1)

# # train 0.5
# data_mirai_05, _, target_mirai_05, _ = train_test_split(data_mirai_train, target_mirai_train, train_size=ratio_05, shuffle=True, random_state = 1)

# train 1.0
data_mirai_1, _, target_mirai_1, _ = train_test_split(data_mirai_train, target_mirai_train, train_size=ratio_1, shuffle=True, random_state = 1)

# # train 2.0
# data_mirai_2, _, target_mirai_2, _ = train_test_split(data_mirai_train, target_mirai_train, train_size=ratio_2, shuffle=True, random_state = 1)

# train 5.0
# data_mirai_5, _, target_mirai_5, _ = train_test_split(data_mirai_train, target_mirai_train, train_size=ratio_5, shuffle=True, random_state = 1)

# %%
# print(data_mirai_001.shape, target_mirai_001.shape)
# print(data_mirai_01.shape, target_mirai_01.shape)
# print(data_mirai_05.shape, target_mirai_05.shape)
print(data_mirai_1.shape, target_mirai_1.shape)
# print(data_mirai_2.shape, target_mirai_2.shape)
# print(data_mirai_5.shape, target_mirai_5.shape)
# Out:
# (9179, 115) (9179,)

# %%
# 0.01
# X_train_mirai_001 = np.vstack([data_benign_train, data_mirai_001])
# y_train_mirai_001 = np.hstack([target_benign_train, target_mirai_001])

# 0.1
# X_train_mirai_01 = np.vstack([data_benign_train, data_mirai_01])
# y_train_mirai_01 = np.hstack([target_benign_train, target_mirai_01])

# # 0.5
# X_train_mirai_05 = np.vstack([data_benign_train, data_mirai_05])
# y_train_mirai_05 = np.hstack([target_benign_train, target_mirai_05])

# 1.0
X_train_mirai_1 = np.vstack([data_benign_train, data_mirai_1])
y_train_mirai_1 = np.hstack([target_benign_train, target_mirai_1])

# # 2.0
# X_train_mirai_2 = np.vstack([data_benign_train, data_mirai_2])
# y_train_mirai_2 = np.hstack([target_benign_train, target_mirai_2])

# 5.0
# X_train_mirai_5 = np.vstack([data_benign_train, data_mirai_5])
# y_train_mirai_5 = np.hstack([target_benign_train, target_mirai_5])

# %%
# print(X_train_mirai_001.shape, y_train_mirai_001.shape)
# print(X_train_mirai_01.shape, y_train_mirai_01.shape)
# print(X_train_mirai_05.shape, y_train_mirai_05.shape)
print(X_train_mirai_1.shape, y_train_mirai_1.shape)
# print(X_train_mirai_2.shape, y_train_mirai_2.shape)
# print(X_train_mirai_5.shape, y_train_mirai_5.shape)
# Out:
# (18358, 115) (18358,)

# %% [markdown]
# ## Get test data

# %% [markdown]
# ### Gafgyt

# %%
X_test_gafgyt = np.vstack([data_benign_test, data_gafgyt_test])
y_test_gafgyt = np.hstack([target_benign_test, target_gafgyt_test])
print(X_test_gafgyt.shape, y_test_gafgyt.shape)
# Out:
# (97123, 115) (97123,)

# %%
data_benign_test.shape, data_gafgyt_test.shape, target_benign_test.shape, target_gafgyt_test.shape
# Out:
# ((3934, 115), (93189, 115), (3934,), (93189,))

# %% [markdown]
# ## Mirai

# %%
X_test_mirai = np.vstack([data_benign_test, data_mirai_test])
y_test_mirai = np.hstack([target_benign_test, target_mirai_test])
print(X_test_mirai.shape, y_test_mirai.shape)
# Out:
# (157574, 115) (157574,)

# %%
X_test_mirai, _ ,y_test_mirai, _ = train_test_split(X_test_mirai, y_test_mirai, train_size=0.7, shuffle=True, random_state=1)

# %%
print(X_test_mirai.shape, y_test_mirai.shape)
# Out:
# (110301, 115) (110301,)

# %% [markdown]
# # 2. SOM train and test

# %% [markdown]
# ## 2.1. Train gafgyt
#
# ## 2.1.1. Rand

# %%
som, winmap, outliers_percentage, scaler = process_train_partial(X_train=X_train_gafgyt_1, y_train=y_train_gafgyt_1, algo='rand')
# Out:
# --------------Training and testing in the same device----------------
# (18358, 115) (18358,)
# ------------Scale data-----------------
# (18358, 115) (18358,)
# X_train_scaled
# [[ 3.45794855e-03  5.41440555e-02  3.63262322e-09 ...  5.57415826e-18
#    3.81797403e-34  2.25198600e-17]
#  [ 4.47850916e-03  1.24129016e-01  6.37556170e-02 ...  1.27110049e-01
#   -9.70281479e-02 -2.36053078e-01]
#  [ 6.77613648e-03  6.51663165e-02  2.18698960e-04 ...  1.35988519e-01
#   -1.59362024e-01 -3.64757266e-01]
#  ...
#  [ 3.62804962e-03  3.33851152e-01  1.05116699e-02 ...  1.47720813e-01
#   -8.32440442e-02 -1.85465097e-01]
#  [ 5.45194536e-03  2.84774544e-01  2.93300948e-02 ...  1.04072329e-01
#   -4.04594790e-02 -1.14390467e-01]
#  [ 3.45794842e-03  3.42912333e-01  0.00000000e+00 ...  9.75485625e-02
#   -3.71231151e-02 -1.12811060e-01]]
# ---------Normalize data--------------
# (18358, 115) (18358,)
# --------------------Train SOM on normalized data--------------
# ---------------------------------Train SOM-------------------------------------
# Number of feature:  115
# The default values of som_x and som_y are None
# Hyper-parameters optimization process. The algorithm used is rand.
# Best: {'learning_rate': 1.056449080701393, 'sigma': 8.594430884287274, 'x': 48.54402238452272}
# ---------SOM has been turned!-----------
# Starting SOM Weights init
# Perform SOM (turned) train random
# /home/ladin/projects/research/papers/SOM-KNN-IoT_AD/utils/minisom.py:370: ComplexWarning: Casting complex values to real discards the imaginary part
#   self._weights[i, j] = c1 * pc[pc_order[0]] + c2 * pc[pc_order[1]]
# 0.5
# Total train time: 113.76072311401367

# %% [markdown]
# ### Test on the same device

# %% [markdown]
# #### Test on gafgyt

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = False)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.964     0.996     0.979      3934
#            2      1.000     0.998     0.999     93189
#
#     accuracy                          0.998     97123
#    macro avg      0.982     0.997     0.989     97123
# weighted avg      0.998     0.998     0.998     97123
# AUC score:  0.9971723612262189
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = True)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.964     0.996     0.979      3934
#            2      1.000     0.998     0.999     93189
#
#     accuracy                          0.998     97123
#    macro avg      0.982     0.997     0.989     97123
# weighted avg      0.998     0.998     0.998     97123
# AUC score:  0.9971723612262189
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# #### Test on Mirai

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = False)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.038     0.996     0.073      2723
#            2      1.000     0.360     0.529    107578
#
#     accuracy                          0.375    110301
#    macro avg      0.519     0.678     0.301    110301
# weighted avg      0.976     0.375     0.518    110301
# AUC score:  0.677991449868038
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = True)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.038     0.996     0.073      2723
#            2      1.000     0.360     0.529    107578
#
#     accuracy                          0.375    110301
#    macro avg      0.519     0.678     0.301    110301
# weighted avg      0.976     0.375     0.518    110301
# AUC score:  0.677991449868038
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# ## 2.1.2. TPE

# %% [markdown]
# ### Train

# %%
som, winmap, outliers_percentage, scaler = process_train_partial(X_train=X_train_gafgyt_1, y_train=y_train_gafgyt_1, algo='tpe')
# Out:
# --------------Training and testing in the same device----------------
# (18358, 115) (18358,)
# ------------Scale data-----------------
# (18358, 115) (18358,)
# X_train_scaled
# [[ 3.45794855e-03  5.41440555e-02  3.63262322e-09 ...  5.57415826e-18
#    3.81797403e-34  2.25198600e-17]
#  [ 4.47850916e-03  1.24129016e-01  6.37556170e-02 ...  1.27110049e-01
#   -9.70281479e-02 -2.36053078e-01]
#  [ 6.77613648e-03  6.51663165e-02  2.18698960e-04 ...  1.35988519e-01
#   -1.59362024e-01 -3.64757266e-01]
#  ...
#  [ 3.62804962e-03  3.33851152e-01  1.05116699e-02 ...  1.47720813e-01
#   -8.32440442e-02 -1.85465097e-01]
#  [ 5.45194536e-03  2.84774544e-01  2.93300948e-02 ...  1.04072329e-01
#   -4.04594790e-02 -1.14390467e-01]
#  [ 3.45794842e-03  3.42912333e-01  0.00000000e+00 ...  9.75485625e-02
#   -3.71231151e-02 -1.12811060e-01]]
# ---------Normalize data--------------
# (18358, 115) (18358,)
# --------------------Train SOM on normalized data--------------
# ---------------------------------Train SOM-------------------------------------
# Number of feature:  115
# The default values of som_x and som_y are None
# Hyper-parameters optimization process. The algorithm used is tpe.
# Best: {'learning_rate': 2.8907979763634333, 'sigma': 8.6826007826758, 'x': 35.99151384867712}
# ---------SOM has been turned!-----------
# Starting SOM Weights init
# Perform SOM (turned) train random
# /home/ladin/projects/research/papers/SOM-KNN-IoT_AD/utils/minisom.py:370: ComplexWarning: Casting complex values to real discards the imaginary part
#   self._weights[i, j] = c1 * pc[pc_order[0]] + c2 * pc[pc_order[1]]
# 0.5
# Total train time: 96.4873366355896

# %% [markdown]
# ### Test on first device

# %% [markdown]
# #### Test on gafgyt

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = False)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.967     0.999     0.982      3934
#            2      1.000     0.999     0.999     93189
#
#     accuracy                          0.999     97123
#    macro avg      0.983     0.999     0.991     97123
# weighted avg      0.999     0.999     0.999     97123
# AUC score:  0.9986348146317904
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = True)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.967     0.998     0.982      3934
#            2      1.000     0.999     0.999     93189
#
#     accuracy                          0.999     97123
#    macro avg      0.983     0.999     0.991     97123
# weighted avg      0.999     0.999     0.999     97123
# AUC score:  0.9985077175296043
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# #### Test on Mirai

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = False)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.053     0.999     0.101      2723
#            2      1.000     0.550     0.710    107578
#
#     accuracy                          0.561    110301
#    macro avg      0.527     0.774     0.405    110301
# weighted avg      0.977     0.561     0.695    110301
# AUC score:  0.7743798849037083
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = True)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.053     0.999     0.101      2723
#            2      1.000     0.550     0.710    107578
#
#     accuracy                          0.561    110301
#    macro avg      0.527     0.774     0.405    110301
# weighted avg      0.977     0.561     0.695    110301
# AUC score:  0.7744356583889933
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# ## 2.1.3. ATPE

# %% [markdown]
# ### Train

# %%
som, winmap, outliers_percentage, scaler = process_train_partial(X_train=X_train_gafgyt_1, y_train=y_train_gafgyt_1, algo='atpe')
# Out:
# --------------Training and testing in the same device----------------
# (18358, 115) (18358,)
# ------------Scale data-----------------
# (18358, 115) (18358,)
# X_train_scaled
# [[ 3.45794855e-03  5.41440555e-02  3.63262322e-09 ...  5.57415826e-18
#    3.81797403e-34  2.25198600e-17]
#  [ 4.47850916e-03  1.24129016e-01  6.37556170e-02 ...  1.27110049e-01
#   -9.70281479e-02 -2.36053078e-01]
#  [ 6.77613648e-03  6.51663165e-02  2.18698960e-04 ...  1.35988519e-01
#   -1.59362024e-01 -3.64757266e-01]
#  ...
#  [ 3.62804962e-03  3.33851152e-01  1.05116699e-02 ...  1.47720813e-01
#   -8.32440442e-02 -1.85465097e-01]
#  [ 5.45194536e-03  2.84774544e-01  2.93300948e-02 ...  1.04072329e-01
#   -4.04594790e-02 -1.14390467e-01]
#  [ 3.45794842e-03  3.42912333e-01  0.00000000e+00 ...  9.75485625e-02
#   -3.71231151e-02 -1.12811060e-01]]
# ---------Normalize data--------------
# (18358, 115) (18358,)
# --------------------Train SOM on normalized data--------------
# ---------------------------------Train SOM-------------------------------------
# Number of feature:  115
# The default values of som_x and som_y are None
# Hyper-parameters optimization process. The algorithm used is atpe.
# Best: {'learning_rate': 0.6346907390093751, 'sigma': 5.4529800499214245, 'x': 44.13857324723201}
# ---------SOM has been turned!-----------
# Starting SOM Weights init
# Perform SOM (turned) train random
# 0.5
# Total train time: 203.37583994865417

# %% [markdown]
# ### Test on the same device

# %% [markdown]
# #### Test on gafgyt

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = False)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.942     0.997     0.969      3934
#            2      1.000     0.997     0.999     93189
#
#     accuracy                          0.997     97123
#    macro avg      0.971     0.997     0.984     97123
# weighted avg      0.998     0.997     0.997     97123
# AUC score:  0.9974413233476466
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = True)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.943     0.997     0.969      3934
#            2      1.000     0.997     0.999     93189
#
#     accuracy                          0.997     97123
#    macro avg      0.971     0.997     0.984     97123
# weighted avg      0.998     0.997     0.997     97123
# AUC score:  0.9974574196680276
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# #### Test on Mirai

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = False)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.039     0.998     0.076      2723
#            2      1.000     0.382     0.553    107578
#
#     accuracy                          0.397    110301
#    macro avg      0.520     0.690     0.314    110301
# weighted avg      0.976     0.397     0.541    110301
# AUC score:  0.6901200254415577
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = True)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.040     0.998     0.077      2723
#            2      1.000     0.394     0.565    107578
#
#     accuracy                          0.409    110301
#    macro avg      0.520     0.696     0.321    110301
# weighted avg      0.976     0.409     0.553    110301
# AUC score:  0.6959808891869331
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# ## 2.1.4. Anneal

# %% [markdown]
# ### Train

# %%
som, winmap, outliers_percentage, scaler = process_train_partial(X_train=X_train_gafgyt_1, y_train=y_train_gafgyt_1, algo='anneal')
# Out:
# --------------Training and testing in the same device----------------
# (18358, 115) (18358,)
# ------------Scale data-----------------
# (18358, 115) (18358,)
# X_train_scaled
# [[ 3.45794855e-03  5.41440555e-02  3.63262322e-09 ...  5.57415826e-18
#    3.81797403e-34  2.25198600e-17]
#  [ 4.47850916e-03  1.24129016e-01  6.37556170e-02 ...  1.27110049e-01
#   -9.70281479e-02 -2.36053078e-01]
#  [ 6.77613648e-03  6.51663165e-02  2.18698960e-04 ...  1.35988519e-01
#   -1.59362024e-01 -3.64757266e-01]
#  ...
#  [ 3.62804962e-03  3.33851152e-01  1.05116699e-02 ...  1.47720813e-01
#   -8.32440442e-02 -1.85465097e-01]
#  [ 5.45194536e-03  2.84774544e-01  2.93300948e-02 ...  1.04072329e-01
#   -4.04594790e-02 -1.14390467e-01]
#  [ 3.45794842e-03  3.42912333e-01  0.00000000e+00 ...  9.75485625e-02
#   -3.71231151e-02 -1.12811060e-01]]
# ---------Normalize data--------------
# (18358, 115) (18358,)
# --------------------Train SOM on normalized data--------------
# ---------------------------------Train SOM-------------------------------------
# Number of feature:  115
# The default values of som_x and som_y are None
# Hyper-parameters optimization process. The algorithm used is anneal.
# Best: {'learning_rate': 2.8107902253066417, 'sigma': 9.097185331151156, 'x': 48.99708287815004}
# ---------SOM has been turned!-----------
# Starting SOM Weights init
# Perform SOM (turned) train random
# 0.5
# Total train time: 104.77047610282898

# %% [markdown]
# ### Test on the same device

# %% [markdown]
# #### Test on gafgyt

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = False)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.964     0.998     0.981      3934
#            2      1.000     0.998     0.999     93189
#
#     accuracy                          0.998     97123
#    macro avg      0.982     0.998     0.990     97123
# weighted avg      0.998     0.998     0.998     97123
# AUC score:  0.9983269660261477
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = True)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.966     0.998     0.981      3934
#            2      1.000     0.998     0.999     93189
#
#     accuracy                          0.998     97123
#    macro avg      0.983     0.998     0.990     97123
# weighted avg      0.999     0.998     0.998     97123
# AUC score:  0.9982320615647239
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# #### Test on Mirai

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = False)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.036     0.999     0.069      2723
#            2      1.000     0.319     0.483    107578
#
#     accuracy                          0.335    110301
#    macro avg      0.518     0.659     0.276    110301
# weighted avg      0.976     0.335     0.473    110301
# AUC score:  0.6586150112249857
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = True)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.036     0.999     0.069      2723
#            2      1.000     0.319     0.483    107578
#
#     accuracy                          0.335    110301
#    macro avg      0.518     0.659     0.276    110301
# weighted avg      0.976     0.335     0.473    110301
# AUC score:  0.6586150112249857
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# ## 2.2. Train Mirai
#
# ## 2.2.1. RAND

# %%
som, winmap, outliers_percentage, scaler = process_train_partial(X_train=X_train_mirai_1, y_train=y_train_mirai_1, algo='rand')
# Out:
# --------------Training and testing in the same device----------------
# (18358, 115) (18358,)
# ------------Scale data-----------------
# (18358, 115) (18358,)
# X_train_scaled
# [[ 2.31515042e-03  5.41440555e-02  3.63262322e-09 ...  5.57415826e-18
#    1.12256067e-33  4.99340799e-17]
#  [ 2.99843163e-03  1.24129016e-01  6.37556170e-02 ...  1.27110049e-01
#   -2.85282147e-01 -5.23408817e-01]
#  [ 4.53672891e-03  6.51663165e-02  2.18698960e-04 ...  1.35988519e-01
#   -4.68556201e-01 -8.08789153e-01]
#  ...
#  [ 2.42903573e-03  3.33851152e-01  1.05116699e-02 ...  1.47720813e-01
#   -2.44754127e-01 -4.11238303e-01]
#  [ 3.65016233e-03  2.84774544e-01  2.93300948e-02 ...  1.04072329e-01
#   -1.18958954e-01 -2.53642017e-01]
#  [ 2.31515033e-03  3.42912333e-01  0.00000000e+00 ...  9.75485625e-02
#   -1.09149378e-01 -2.50139944e-01]]
# ---------Normalize data--------------
# (18358, 115) (18358,)
# --------------------Train SOM on normalized data--------------
# ---------------------------------Train SOM-------------------------------------
# Number of feature:  115
# The default values of som_x and som_y are None
# Hyper-parameters optimization process. The algorithm used is rand.
# Best: {'learning_rate': 1.7556005639271506, 'sigma': 8.784345867716597, 'x': 49.29931508516177}
# ---------SOM has been turned!-----------
# Starting SOM Weights init
# Perform SOM (turned) train random
# 0.5
# Total train time: 104.75247001647949

# %% [markdown]
# ### Test on the same device

# %% [markdown]
# #### Test on gafgyt

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = False)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.521     0.997     0.684      3934
#            2      1.000     0.961     0.980     93189
#
#     accuracy                          0.963     97123
#    macro avg      0.760     0.979     0.832     97123
# weighted avg      0.980     0.963     0.968     97123
# AUC score:  0.9790948650348495
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = True)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.522     0.997     0.685      3934
#            2      1.000     0.962     0.980     93189
#
#     accuracy                          0.963     97123
#    macro avg      0.761     0.979     0.833     97123
# weighted avg      0.981     0.963     0.968     97123
# AUC score:  0.9791019039358397
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# #### Test on Mirai

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = False)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.948     0.998     0.972      2723
#            2      1.000     0.999     0.999    107578
#
#     accuracy                          0.999    110301
#    macro avg      0.974     0.998     0.986    110301
# weighted avg      0.999     0.999     0.999    110301
# AUC score:  0.9982011053964776
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = True)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.949     0.997     0.973      2723
#            2      1.000     0.999     0.999    107578
#
#     accuracy                          0.999    110301
#    macro avg      0.975     0.998     0.986    110301
# weighted avg      0.999     0.999     0.999    110301
# AUC score:  0.9980407233424365
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# ## 2.2.2. TPE

# %% [markdown]
# ### Train

# %%
som, winmap, outliers_percentage, scaler = process_train_partial(X_train=X_train_mirai_1, y_train=y_train_mirai_1, algo='tpe')
# Out:
# --------------Training and testing in the same device----------------
# (18358, 115) (18358,)
# ------------Scale data-----------------
# (18358, 115) (18358,)
# X_train_scaled
# [[ 2.31515042e-03  5.41440555e-02  3.63262322e-09 ...  5.57415826e-18
#    1.12256067e-33  4.99340799e-17]
#  [ 2.99843163e-03  1.24129016e-01  6.37556170e-02 ...  1.27110049e-01
#   -2.85282147e-01 -5.23408817e-01]
#  [ 4.53672891e-03  6.51663165e-02  2.18698960e-04 ...  1.35988519e-01
#   -4.68556201e-01 -8.08789153e-01]
#  ...
#  [ 2.42903573e-03  3.33851152e-01  1.05116699e-02 ...  1.47720813e-01
#   -2.44754127e-01 -4.11238303e-01]
#  [ 3.65016233e-03  2.84774544e-01  2.93300948e-02 ...  1.04072329e-01
#   -1.18958954e-01 -2.53642017e-01]
#  [ 2.31515033e-03  3.42912333e-01  0.00000000e+00 ...  9.75485625e-02
#   -1.09149378e-01 -2.50139944e-01]]
# ---------Normalize data--------------
# (18358, 115) (18358,)
# --------------------Train SOM on normalized data--------------
# ---------------------------------Train SOM-------------------------------------
# Number of feature:  115
# The default values of som_x and som_y are None
# Hyper-parameters optimization process. The algorithm used is tpe.
# Best: {'learning_rate': 1.7875575584857177, 'sigma': 7.066326914266141, 'x': 43.19662201759497}
# ---------SOM has been turned!-----------
# Starting SOM Weights init
# Perform SOM (turned) train random
# 0.5
# Total train time: 105.17118382453918

# %% [markdown]
# ### Test on the same device

# %% [markdown]
# #### Test on gafgyt

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = False)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.413     0.998     0.584      3934
#            2      1.000     0.940     0.969     93189
#
#     accuracy                          0.942     97123
#    macro avg      0.706     0.969     0.777     97123
# weighted avg      0.976     0.942     0.953     97123
# AUC score:  0.9692714342772892
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = True)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.413     0.998     0.584      3934
#            2      1.000     0.940     0.969     93189
#
#     accuracy                          0.942     97123
#    macro avg      0.706     0.969     0.777     97123
# weighted avg      0.976     0.942     0.953     97123
# AUC score:  0.9691550680553571
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# #### Test on Mirai

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = False)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.936     0.999     0.966      2723
#            2      1.000     0.998     0.999    107578
#
#     accuracy                          0.998    110301
#    macro avg      0.968     0.998     0.983    110301
# weighted avg      0.998     0.998     0.998    110301
# AUC score:  0.998405674743549
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = True)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.951     0.999     0.974      2723
#            2      1.000     0.999     0.999    107578
#
#     accuracy                          0.999    110301
#    macro avg      0.975     0.999     0.987    110301
# weighted avg      0.999     0.999     0.999    110301
# AUC score:  0.9986148253133681
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# ## 2.2.3. ATPE

# %% [markdown]
# ### Train

# %%
som, winmap, outliers_percentage, scaler = process_train_partial(X_train=X_train_mirai_1, y_train=y_train_mirai_1, algo='atpe')
# Out:
# --------------Training and testing in the same device----------------
# (18358, 115) (18358,)
# ------------Scale data-----------------
# (18358, 115) (18358,)
# X_train_scaled
# [[ 2.31515042e-03  5.41440555e-02  3.63262322e-09 ...  5.57415826e-18
#    1.12256067e-33  4.99340799e-17]
#  [ 2.99843163e-03  1.24129016e-01  6.37556170e-02 ...  1.27110049e-01
#   -2.85282147e-01 -5.23408817e-01]
#  [ 4.53672891e-03  6.51663165e-02  2.18698960e-04 ...  1.35988519e-01
#   -4.68556201e-01 -8.08789153e-01]
#  ...
#  [ 2.42903573e-03  3.33851152e-01  1.05116699e-02 ...  1.47720813e-01
#   -2.44754127e-01 -4.11238303e-01]
#  [ 3.65016233e-03  2.84774544e-01  2.93300948e-02 ...  1.04072329e-01
#   -1.18958954e-01 -2.53642017e-01]
#  [ 2.31515033e-03  3.42912333e-01  0.00000000e+00 ...  9.75485625e-02
#   -1.09149378e-01 -2.50139944e-01]]
# ---------Normalize data--------------
# (18358, 115) (18358,)
# --------------------Train SOM on normalized data--------------
# ---------------------------------Train SOM-------------------------------------
# Number of feature:  115
# The default values of som_x and som_y are None
# Hyper-parameters optimization process. The algorithm used is atpe.
# Best: {'learning_rate': 3.2354879407632002, 'sigma': 8.357699564050499, 'x': 48.33873186076374}
# ---------SOM has been turned!-----------
# Starting SOM Weights init
# Perform SOM (turned) train random
# 0.5
# Total train time: 408.1961097717285

# %% [markdown]
# ### Test on the same device

# %% [markdown]
# #### Test on gafgyt

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = False)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.406     0.998     0.577      3934
#            2      1.000     0.938     0.968     93189
#
#     accuracy                          0.941     97123
#    macro avg      0.703     0.968     0.773     97123
# weighted avg      0.976     0.941     0.952     97123
# AUC score:  0.968126577011826
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = True)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.406     0.998     0.577      3934
#            2      1.000     0.938     0.968     93189
#
#     accuracy                          0.941     97123
#    macro avg      0.703     0.968     0.773     97123
# weighted avg      0.976     0.941     0.952     97123
# AUC score:  0.9681373078920802
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# #### Test on Mirai

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = False)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.914     1.000     0.955      2723
#            2      1.000     0.998     0.999    107578
#
#     accuracy                          0.998    110301
#    macro avg      0.957     0.999     0.977    110301
# weighted avg      0.998     0.998     0.998    110301
# AUC score:  0.9986265446410081
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn = True)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.921     1.000     0.959      2723
#            2      1.000     0.998     0.999    107578
#
#     accuracy                          0.998    110301
#    macro avg      0.960     0.999     0.979    110301
# weighted avg      0.998     0.998     0.998    110301
# AUC score:  0.9987287960306974
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# ## 2.2.4. ANNEAL

# %% [markdown]
# ### Train

# %%
som, winmap, outliers_percentage, scaler = process_train_partial(X_train=X_train_mirai_1, y_train=y_train_mirai_1, algo='anneal')
# Out:
# --------------Training and testing in the same device----------------
# (18358, 115) (18358,)
# ------------Scale data-----------------
# (18358, 115) (18358,)
# X_train_scaled
# [[ 2.31515042e-03  5.41440555e-02  3.63262322e-09 ...  5.57415826e-18
#    1.12256067e-33  4.99340799e-17]
#  [ 2.99843163e-03  1.24129016e-01  6.37556170e-02 ...  1.27110049e-01
#   -2.85282147e-01 -5.23408817e-01]
#  [ 4.53672891e-03  6.51663165e-02  2.18698960e-04 ...  1.35988519e-01
#   -4.68556201e-01 -8.08789153e-01]
#  ...
#  [ 2.42903573e-03  3.33851152e-01  1.05116699e-02 ...  1.47720813e-01
#   -2.44754127e-01 -4.11238303e-01]
#  [ 3.65016233e-03  2.84774544e-01  2.93300948e-02 ...  1.04072329e-01
#   -1.18958954e-01 -2.53642017e-01]
#  [ 2.31515033e-03  3.42912333e-01  0.00000000e+00 ...  9.75485625e-02
#   -1.09149378e-01 -2.50139944e-01]]
# ---------Normalize data--------------
# (18358, 115) (18358,)
# --------------------Train SOM on normalized data--------------
# ---------------------------------Train SOM-------------------------------------
# Number of feature:  115
# The default values of som_x and som_y are None
# Hyper-parameters optimization process. The algorithm used is anneal.
# Best: {'learning_rate': 3.7201118510962186, 'sigma': 5.106011032567708, 'x': 33.45171912282071}
# ---------SOM has been turned!-----------
# Starting SOM Weights init
# Perform SOM (turned) train random
# 0.5
# Total train time: 94.68189001083374

# %% [markdown]
# ### Test on the same device

# %% [markdown]
# #### Test on gafgyt

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = False)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.859     0.997     0.923      3934
#            2      1.000     0.993     0.996     93189
#
#     accuracy                          0.993     97123
#    macro avg      0.929     0.995     0.960     97123
# weighted avg      0.994     0.993     0.993     97123
# AUC score:  0.9952629546560626
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_gafgyt, y_test=y_test_gafgyt, using_knn = True)
# Out:
# Shape:  (97123, 115) (97123,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (97123, 115) (97123,)
# Normalize data
# Shape:  (97123, 115) (97123,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.859     0.997     0.923      3934
#            2      1.000     0.993     0.996     93189
#
#     accuracy                          0.993     97123
#    macro avg      0.929     0.995     0.960     97123
# weighted avg      0.994     0.993     0.993     97123
# AUC score:  0.9952629546560626
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %% [markdown]
# #### Test on Mirai

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn=False)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.970     0.998     0.984      2723
#            2      1.000     0.999     1.000    107578
#
#     accuracy                          0.999    110301
#    macro avg      0.985     0.999     0.992    110301
# weighted avg      0.999     0.999     0.999    110301
# AUC score:  0.9986961283622292
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------

# %%
som_test(som=som, winmap=winmap, outliers_percentage=outliers_percentage, scaler=scaler, X_test=X_test_mirai, y_test=y_test_mirai, using_knn=True)
# Out:
# Shape:  (110301, 115) (110301,)
# ----------------------Test is starting----------------------
# Scale data
# Shape:  (110301, 115) (110301,)
# Normalize data
# Shape:  (110301, 115) (110301,)
# Testing
# ----------------------------------------------------------------------
# SOM classification
#               precision    recall  f1-score   support
#
#            1      0.970     0.998     0.984      2723
#            2      1.000     0.999     1.000    107578
#
#     accuracy                          0.999    110301
#    macro avg      0.985     0.999     0.992    110301
# weighted avg      0.999     0.999     0.999    110301
# AUC score:  0.9986961283622292
# -----------Testing SOM done!-------------
# ----------------------Test Done----------------------
